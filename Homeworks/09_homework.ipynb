# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # F
#
# # F
#
# # T
#
# # T

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # article
#
# # footer
#
# # nav

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
<form action :"/index.html">
    <div>ID : <input type="text" name="name" autofocus></div>
    <div>PWD : <input type="password" name="pwd"></div>
    <div> <input type="submit" value="로그인"></div>
</form>
# Out:
#   File "<ipython-input-1-fcad99f0b27d>", line 1
#     <form action :"/index.html">
#     ^
# SyntaxError: invalid syntax

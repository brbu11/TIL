# %% [markdown]
# ### 1.
# > web에서의 커뮤니케이션 방식은 _(a)_과(와) (b)로 이루어져 있다. 브러우저의 주소창에 주소를 입력하는 것으로 (a)을(를) 보내며, 그에 대한 (b)로 HTML,XML,JSON 등의 문서를 보내준다. 각각 (a),(b)에 들어갈 말을 작성 하시오.

# %% [markdown]
# a = 요청
#
# b = 응답

# %% [markdown]
# ### 2.
# > Flask Web Framework는 python에 내장되어 있는 모듈이 아니므로 별도의 설치가 필요하다. Flask를 설치하기 위하여 bash에서 어떤 명령어를 입력해야 하는지 작성하시오.

# %% [markdown]
# pip install flask

# %% [markdown]
# ## 3.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# (a) = from flask import Flask
#
# flask라는 패키지에서 Flask 모듈(클래스)을 import 해줌으로써 플라스크를 사용할 수 있도록 설정

# %% [markdown]
# # 4.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### python app.py

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## (3) Cascading Style Sheets

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### F
# ### T
# ### T

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### rem

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 후손 셀렉터는 div 안의 p를 포함한 그 밑에 모든 요소에 영향을 주고
#
# #### 자식 셀렉터는  div 안의 p영역에만 영향을 미침
